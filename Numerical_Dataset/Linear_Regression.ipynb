# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
data = np.load('creditcard_preprocessed.npz')

X_train = data['X_train']
y_train = data['y_train']
X_val = data['X_val']
y_val = data['y_val']
X_test = data['X_test']
y_test = data['y_test']

print(f"Train shape: {X_train.shape}, Validation shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (341178, 29), Validation shape: (113726, 29), Test shape: (113726, 29)

# %%
# Initialize SGDRegressor & training hyperparameters
max_epochs = 50
patience = 5
best_val_loss = float('inf')
epochs_no_improve = 0
best_epoch = 0

model = SGDRegressor(
    loss='squared_error',
    penalty='l2',
    alpha=0.0001,
    eta0=0.01,
    learning_rate='constant',
    max_iter=1000,
    random_state=42,
    warm_start=True,
    shuffle=False
)

training_losses = []
validation_losses = []

print("Starting training with Early Stopping...")
# Out:
# Starting training with Early Stopping...

# %%
# Training loop with Early Stopping
for epoch in range(max_epochs):
    model.fit(X_train, y_train)
    
    # Training loss
    y_train_pred = model.predict(X_train)
    train_loss = mean_squared_error(y_train, y_train_pred)
    training_losses.append(train_loss)
    
    # Validation loss
    y_val_pred = model.predict(X_val)
    val_loss = mean_squared_error(y_val, y_val_pred)
    validation_losses.append(val_loss)
    
    # Early stopping check
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0
        best_epoch = epoch + 1
    else:
        epochs_no_improve += 1
    
    if epochs_no_improve >= patience:
        print(f"\nEarly stopping triggered at Epoch {epoch + 1}.")
        break
    
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch + 1}/{max_epochs}, Train MSE: {train_loss:.6f}, Val MSE: {val_loss:.6f}")

print(f"\nTraining stopped. \nBest model epoch: {best_epoch} \nVal MSE: {best_val_loss:.6f}")
# Out:
# Early stopping triggered at Epoch 1.
#
# Training stopped.
# Best model epoch: 1
# Val MSE: 0.103400

# %%
# Evaluate on Test Set
y_pred_cont = model.predict(X_test)

# Binarize predictions at 0.5 threshold for classification metrics
THRESHOLD = 0.5
y_pred_bin = (y_pred_cont >= THRESHOLD).astype(int)

# Metrics
test_mse = mean_squared_error(y_test, y_pred_cont)
test_r2 = r2_score(y_test, y_pred_cont)
accuracy = accuracy_score(y_test, y_pred_bin)
auc_score = roc_auc_score(y_test, y_pred_cont)

print(f"\n--- Testing Data Results ---")
print(f"Test Set Accuracy (0.5 threshold): {accuracy:.4f}")
print(f"Test Set MSE: {test_mse:.6f}")
print(f"Test Set R²: {test_r2:.4f}")
print(f"Test Set AUC: {auc_score:.4f}")
# Out:
# --- Testing Data Results ---
# Test Set Accuracy (0.5 threshold): 0.9152
# Test Set MSE: 0.102807
# Test Set R²: 0.5888
# Test Set AUC: 0.9585

# %%
# Plot Training & Validation Loss Curve
epochs_plot = range(1, len(training_losses) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epochs_plot, training_losses, label='Training MSE', color='b')
plt.plot(epochs_plot, validation_losses, label='Validation MSE', color='r')
plt.axvline(x=best_epoch, color='g', linestyle='--', label=f'Early Stop ({best_epoch} epochs)')
plt.title('Training and Validation Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_bin)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Class 0 (Non-Fraud)', 'Class 1 (Fraud)'],
            yticklabels=['Class 0 (Non-Fraud)', 'Class 1 (Fraud)'])
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_cont)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {auc_score:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
